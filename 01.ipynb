# %%
# !pip install catboost matplotlib pandas scikit-learn kaggle optuna ipywidgets kaleido shap jupyterlab-rise
# Out:
# Requirement already satisfied: catboost in ./.venv/lib/python3.11/site-packages (1.2.8)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: kaggle in ./.venv/lib/python3.11/site-packages (1.7.4.2)
# Requirement already satisfied: optuna in ./.venv/lib/python3.11/site-packages (4.3.0)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.11/site-packages (8.1.7)
# Requirement already satisfied: kaleido in ./.venv/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: shap in ./.venv/lib/python3.11/site-packages (0.47.2)
# Requirement already satisfied: jupyterlab-rise in ./.venv/lib/python3.11/site-packages (0.43.1)
# Requirement already satisfied: graphviz in ./.venv/lib/python3.11/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in ./.venv/lib/python3.11/site-packages (from catboost) (2.2.5)
# Requirement already satisfied: scipy in ./.venv/lib/python3.11/site-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in ./.venv/lib/python3.11/site-packages (from catboost) (6.0.1)
# Requirement already satisfied: six in ./.venv/lib/python3.11/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: bleach in ./.venv/lib/python3.11/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in ./.venv/lib/python3.11/site-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in ./.venv/lib/python3.11/site-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in ./.venv/lib/python3.11/site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.11/site-packages (from kaggle) (6.30.2)
# Requirement already satisfied: python-slugify in ./.venv/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in ./.venv/lib/python3.11/site-packages (from kaggle) (65.5.1)
# Requirement already satisfied: text-unidecode in ./.venv/lib/python3.11/site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in ./.venv/lib/python3.11/site-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.11/site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: alembic>=1.5.0 in ./.venv/lib/python3.11/site-packages (from optuna) (1.15.2)
# Requirement already satisfied: colorlog in ./.venv/lib/python3.11/site-packages (from optuna) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in ./.venv/lib/python3.11/site-packages (from optuna) (2.0.40)
# Requirement already satisfied: PyYAML in ./.venv/lib/python3.11/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: comm>=0.1.3 in ./.venv/lib/python3.11/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in ./.venv/lib/python3.11/site-packages (from ipywidgets) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in ./.venv/lib/python3.11/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.11/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.11/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: slicer==0.0.8 in ./.venv/lib/python3.11/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in ./.venv/lib/python3.11/site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.11/site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.11/site-packages (from shap) (4.13.2)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in ./.venv/lib/python3.11/site-packages (from jupyterlab-rise) (2.15.0)
# Requirement already satisfied: jupyterlab-mathjax3 in ./.venv/lib/python3.11/site-packages (from jupyterlab-rise) (4.3.0)
# Requirement already satisfied: jupyterlab<5,>=4.1.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab-rise) (4.4.2)
# Requirement already satisfied: anyio>=3.1.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (23.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (6.4.2)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (2.2.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.2.4)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (4.23.0)
# Requirement already satisfied: Mako in ./.venv/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-rise) (21.2.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.16.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (1.8.14)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (1.6.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.1.0->jupyterlab-rise) (7.0.0)
# Requirement already satisfied: decorator in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-rise) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.1.0->jupyterlab-rise) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-rise) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (3.3.0)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.1.1)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.5.1)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (3.0.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (4.13.4)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (2.21.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./.venv/lib/python3.11/site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.11/site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.1)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-rise) (2.22)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-rise) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-rise) (2.9.0.20241206)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.11/site-packages (from plotly->catboost) (1.38.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.11/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
#!dir ../../../home/vscode

# %%
import os
from pathlib import Path
container_check = os.getenv("iscontainer")
if container_check=="y":
    config_dir = Path("/home/vscode/.config/kaggle")
    config_dir.mkdir(parents=True, exist_ok=True)
    
    with open(config_dir / "kaggle.json", "w") as dst:
        with open("./kaggle.json", "r") as src:
            dst.write(src.read())

# %% [markdown]
# # Download dataset

# %%
import os
import zipfile
from pathlib import Path
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()



dataset_name = "fedesoriano/stroke-prediction-dataset"
download_folder = Path("data/stroke-prediction")
download_folder.mkdir(parents=True, exist_ok=True)

api.dataset_download_files(dataset_name, path=str(download_folder), unzip=True)
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /home/vscode/.config/kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset

# %%
# !dir "./data/stroke-prediction"
# Out:
# healthcare-dataset-stroke-data.csv

# %% [markdown]
# # Load data

# %%
import pandas as pd

df = pd.read_csv(download_folder / "healthcare-dataset-stroke-data.csv")
df_ids = df.pop("id")

df.head(5)
# Out:
#    gender   age  hypertension  ...   bmi   smoking_status stroke
# 0    Male  67.0             0  ...  36.6  formerly smoked      1
# 1  Female  61.0             0  ...   NaN     never smoked      1
# 2    Male  80.0             0  ...  32.5     never smoked      1
# 3  Female  49.0             0  ...  34.4           smokes      1
# 4  Female  79.0             1  ...  24.0     never smoked      1
#
# [5 rows x 11 columns]

# %% [markdown]
# # Ordinal encoder for categorical features

# %%
from sklearn.preprocessing import OrdinalEncoder

def create_ordinal_encoder(categories_order):
    return OrdinalEncoder(categories=categories_order)

smoking_status = [['formerly smoked', 'never smoked', 'smokes','Unknown']]  

ordinal_encoder_smoking_status = create_ordinal_encoder(smoking_status)

# %% [markdown]
# # One-hot encoding categorical non-order features

# %%
from sklearn.preprocessing import OneHotEncoder

hot_encoder = OneHotEncoder(drop='first')

# %% [markdown]
# # Pipeline for transforming columns

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('ever_married', hot_encoder, ['ever_married']),
        ('work_type', hot_encoder, ['work_type']),
        ('gender', hot_encoder, ['gender']),
        ('Residence_type', hot_encoder, ['Residence_type']),
        ('smoking_status', ordinal_encoder_smoking_status, ['smoking_status'])
    ],
    remainder='passthrough'  
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

encoded_data = preprocessor.fit_transform(df)

encoded_data
# Out:
# array([[  1.  ,   0.  ,   1.  , ..., 228.69,  36.6 ,   1.  ],
#        [  1.  ,   0.  ,   0.  , ..., 202.21,    nan,   1.  ],
#        [  1.  ,   0.  ,   1.  , ..., 105.92,  32.5 ,   1.  ],
#        ...,
#        [  1.  ,   0.  ,   0.  , ...,  82.99,  30.6 ,   0.  ],
#        [  1.  ,   0.  ,   1.  , ..., 166.29,  25.6 ,   0.  ],
#        [  1.  ,   0.  ,   0.  , ...,  85.28,  26.2 ,   0.  ]],
#       shape=(5110, 15))

# %% [markdown]
# # Creation of a data frame from transformed data

# %%
transformed_df = pd.DataFrame(
  encoded_data,
  columns=preprocessor.get_feature_names_out())

transformed_df
# Out:
#       ever_married__ever_married_Yes  ...  remainder__stroke
# 0                                1.0  ...                1.0
# 1                                1.0  ...                1.0
# 2                                1.0  ...                1.0
# 3                                1.0  ...                1.0
# 4                                1.0  ...                1.0
# ...                              ...  ...                ...
# 5105                             1.0  ...                0.0
# 5106                             1.0  ...                0.0
# 5107                             1.0  ...                0.0
# 5108                             1.0  ...                0.0
# 5109                             1.0  ...                0.0
#
# [5110 rows x 15 columns]

# %% [markdown]
# # Division into training and test data

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(transformed_df, test_size=0.2, random_state=42)

df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1022 entries, 4688 to 2902
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ever_married__ever_married_Yes        1022 non-null   float64
#  1   work_type__work_type_Never_worked     1022 non-null   float64
#  2   work_type__work_type_Private          1022 non-null   float64
#  3   work_type__work_type_Self-employed    1022 non-null   float64
#  4   work_type__work_type_children         1022 non-null   float64
#  5   gender__gender_Male                   1022 non-null   float64
#  6   gender__gender_Other                  1022 non-null   float64
#  7   Residence_type__Residence_type_Urban  1022 non-null   float64
#  8   smoking_status__smoking_status        1022 non-null   float64
#  9   remainder__age                        1022 non-null   float64
#  10  remainder__hypertension               1022 non-null   float64
#  11  remainder__heart_disease              1022 non-null   float64
#  12  remainder__avg_glucose_level          1022 non-null   float64
#  13  remainder__bmi                        977 non-null    float64
#  14  remainder__stroke                     1022 non-null   float64
# dtypes: float64(15)
# memory usage: 127.8 KB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4088 entries, 802 to 860
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ever_married__ever_married_Yes        4088 non-null   float64
#  1   work_type__work_type_Never_worked     4088 non-null   float64
#  2   work_type__work_type_Private          4088 non-null   float64
#  3   work_type__work_type_Self-employed    4088 non-null   float64
#  4   work_type__work_type_children         4088 non-null   float64
#  5   gender__gender_Male                   4088 non-null   float64
#  6   gender__gender_Other                  4088 non-null   float64
#  7   Residence_type__Residence_type_Urban  4088 non-null   float64
#  8   smoking_status__smoking_status        4088 non-null   float64
#  9   remainder__age                        4088 non-null   float64
#  10  remainder__hypertension               4088 non-null   float64
#  11  remainder__heart_disease              4088 non-null   float64
#  12  remainder__avg_glucose_level          4088 non-null   float64
#  13  remainder__bmi                        3932 non-null   float64
#  14  remainder__stroke                     4088 non-null   float64
# dtypes: float64(15)
# memory usage: 511.0 KB

# %%
y_train = df_train.pop("remainder__stroke")
X_train = df_train
# Out:
# 802     0.0
# 3927    0.0
# 2337    0.0
# 3910    0.0
# 1886    0.0
#        ...
# 4426    0.0
# 466     0.0
# 3092    0.0
# 3772    0.0
# 860     0.0
# Name: remainder__stroke, Length: 4088, dtype: float64

# %%
y_test = df_test.pop("remainder__stroke")
X_test = df_test

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4088 entries, 802 to 860
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ever_married__ever_married_Yes        4088 non-null   float64
#  1   work_type__work_type_Never_worked     4088 non-null   float64
#  2   work_type__work_type_Private          4088 non-null   float64
#  3   work_type__work_type_Self-employed    4088 non-null   float64
#  4   work_type__work_type_children         4088 non-null   float64
#  5   gender__gender_Male                   4088 non-null   float64
#  6   gender__gender_Other                  4088 non-null   float64
#  7   Residence_type__Residence_type_Urban  4088 non-null   float64
#  8   smoking_status__smoking_status        4088 non-null   float64
#  9   remainder__age                        4088 non-null   float64
#  10  remainder__hypertension               4088 non-null   float64
#  11  remainder__heart_disease              4088 non-null   float64
#  12  remainder__avg_glucose_level          4088 non-null   float64
#  13  remainder__bmi                        3932 non-null   float64
# dtypes: float64(14)
# memory usage: 479.1 KB

# %%
# Out:
# 4356    0.0
# 1055    0.0
# 1002    0.0
# 1305    0.0
# 1721    0.0
# 745     0.0
# 2649    0.0
# 3518    0.0
# 3555    0.0
# 2569    0.0
# 2610    0.0
# 1175    0.0
# 3667    0.0
# 1438    0.0
# 2091    0.0
# 2312    0.0
# 1788    0.0
# 2018    0.0
# 2877    0.0
# 1730    0.0
# 2172    0.0
# 1129    0.0
# 893     0.0
# 1934    0.0
# 62      1.0
# 2622    0.0
# 2867    0.0
# 1281    0.0
# 478     0.0
# 1413    0.0
# 1183    0.0
# 4353    0.0
# 1503    0.0
# 2194    0.0
# 3849    0.0
# 3742    0.0
# 1038    0.0
# 3733    0.0
# 4019    0.0
# 731     0.0
# 3887    0.0
# 2629    0.0
# 227     1.0
# 2313    0.0
# 1397    0.0
# 287     0.0
# 2902    0.0
# 1545    0.0
# 4666    0.0
# 1456    0.0
# Name: remainder__stroke, dtype: float64
